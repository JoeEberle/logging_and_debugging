# %% [markdown]
# ![logging_and_debugging.png](attachment:logging_and_debugging.png)

# %% [markdown]
# ![developer.png](attachment:developer.png)

# %% [markdown]
# ## Step 0 - Import any necessary LIbraries

# %%
# Install any libraries you dont already have installed 
# import configparser   
# from datetime import date, datetime

# import system_info as si                       # "C:\Users\josep\system_info.py"

# %% [markdown]
# ## Step 0 - Read any initial configuration files and settings

# %%
# Install any libraries you dont already have installed 
import configparser   
from datetime import date, datetime

# establish the configuration settings parser
config = configparser.ConfigParser()  
cfg = config.read('c:\\user\josep\\config.ini')   

# Establish some parameters 
solution_name = 'logging_and_debugging'

# %% [markdown]
# ## Step 0 - Optional - Establish Logging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_Start(solution_name, start_time)

# %% [markdown]
# ## Step 1 - Provide Samples of each logging level

# %%
logging.info(f'{solution_name} Step 1 - Provide examples of logging Levels')  
logging.debug(f'{solution_name} LOGGING LEVEL 10 -debug -Level 10 is for DEBUGGING')  
logging.info(f'{solution_name} LOGGING LEVEL 20 -info -Level 20 is for general information')  
logging.warning(f'{solution_name} LOGGING LEVEL 30 -warning -Level 30 is to produce warnings. ')  
logging.error(f'{solution_name} LOGGING LEVEL 40 -error -Level 40 is for error messages that dont stop the code')  
logging.critical(f'{solution_name} LOGGING LEVEL 50 -critical -Level 50 is for critical level errors that stop code')

# %% [markdown]
# ## Step 0 - Optional Step Produce Education and  Documention

# %%
# Introduction - Overview of Solution  
def get_solution_introduction():
    ''' the get_solution_introduction function returns the and overview or introduction of what the solution does. '''  
    solution_introduction = '\n'   # Start with a new line to separate documentation and make it more readable.     
    solution_introduction = solution_introduction + 'This solution creates a log of information about the solution itself.\n'
    solution_introduction = solution_introduction +  'The log file enables you to quickly and easily debug and track performance of any solution.\n'
    solution_introduction = solution_introduction +  'The file will be easily modifyable and extensible to track information as needed.\n'  
    solution_introduction = solution_introduction +  'The current log file is automatically appended to the historical log so that performance and functionality can be tracked over time.\n'        
    return solution_introduction 

def get_credits(): 
    ''' the get_credits function will return who contributed to the solution and when. '''         
    solution_credits = ''   # Start with a new line to separate documentation and make it more readable.   
    solution_credits = solution_credits + '\nThis data science solution was developed:' 
    solution_credits = solution_credits + '\nIn collaboration by Joe Eberle and others.' 
    solution_credits = solution_credits + '\nThe solution was developed in Python starting on 1/15/2023'
    solution_credits = solution_credits + '\nThis solution is free and open source and the code is openly available for general use.'   
    return solution_credits 
    
# get_solution_steps- Overview of solution Process Steps 
def get_solution_steps():
    ''' the get_solution_steps function will return high levels steps needed for the solution. '''        
    solution_steps = '\n'   # Start with a new line to separate documentation and make it more readable.     
    solution_steps = solution_steps + '\nThe high level steps for this solution are:\n'
    solution_steps = solution_steps + 'Step 1: Turn on the logger engine.\n'
    solution_steps = solution_steps + 'Step 2: Insert logging and debugging throughout code\n'
    solution_steps = solution_steps + 'Step 3: Inspect the logging at the end of the solution.\n' 
    solution_steps = solution_steps + 'Optional Step 4: Inspect the historical log to analyze performnce over time.\n'     
    return solution_steps 


#  get_solution_notes
def get_solution_notes():
    ''' the get_solution_notes function returns any special or helpful notes about the solution.'''  
    solution_notes = '\n'   # Start with a new line to separate documentation and make it more readable. 
    solution_notes = solution_notes + '\nSome additional notes for this solution are:\n'
    solution_notes = solution_notes + 'Note 1: The log file is kept by default in the current working directory.\n'  
    solution_notes = solution_notes + 'Note 2: Logging is designed to persist even if the process fails.\n' 
    solution_notes = solution_notes + 'Note 3: Each solution gets its own log file to keep things brief and simple.\n'     
    solution_notes = solution_notes + 'Note 4: Each log file gets reset every time the solution is run.\n'
    solution_notes = solution_notes + 'Note 5: Each log file is appended to a historical log for anaylsis over time.\n'    
    solution_notes = solution_notes + 'Note 6: There are 5 levels of logging you can use to organize the log file \n'        
    solution_notes = solution_notes + 'Note 7: It is up to you how much logging you think is necessary for your solution\n'       
    return solution_notes

# %%
talking_solution = True
if talking_solution:
    print(get_solution_introduction()) 
    ql.talk(get_solution_introduction())
    print(get_credits()) 
    ql.talk(get_credits())
    print(get_solution_steps()) 
    ql.talk(get_solution_steps())
    print(get_solution_notes()) 
    ql.talk(get_solution_notes())    
else:
    print(get_solution_introduction()) 
    print(get_credits())     
    print(get_solution_steps()) 
    print(get_solution_notes())
# Out:
# This solution creates a log of information about the solution itself.
# The log file enables you to quickly and easily debug and track performance of any solution.
# The file will be easily modifyable and extensible to track information as needed.
# The current log file is automatically appended to the historical log so that performance and functionality can be tracked over time.
#
#
# This data science solution was developed:
# In collaboration by Joe Eberle and others.
# The solution was developed in Python starting on 1/15/2023
# This solution is free and open source and the code is openly available for general use.
#
#
# The high level steps for this solution are:
# Step 1: Turn on the logger engine.
# Step 2: Insert logging and debugging throughout code
# Step 3: Inspect the logging at the end of the solution.
# Optional Step 4: Inspect the historical log to analyze performnce over time.
#
#
#
# Some additional notes for this solution are:
# Note 1: The log file is kept by default in the current working directory.
# Note 2: Logging is designed to persist even if the process fails.
# Note 3: Each solution gets its own log file to keep things brief and simple.
# Note 4: Each log file gets reset every time the solution is run.
# Note 5: Each log file is appended to a historical log for anaylsis over time.
# Note 6: There are 5 levels of logging you can use to organize the log file
# Note 7: It is up to you how much logging you think is necessary for your solution

# %% [markdown]
# ## Optional - evaluate performance and  Append the Log File to Historical Log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2023-08-20 21:55:11,951 - INFO - START logging_and_debugging =============================================
# 2023-08-20 21:55:11,951 - INFO - START logging_and_debugging Start Time = 2023-08-20 21:55:11
# 2023-08-20 21:55:11,951 - INFO - logging_and_debugging Step 0 - Initialize the configuration file parser
# 2023-08-20 21:55:11,962 - INFO - logging_and_debugging Step 1 - Provide examples of logging Levels
# 2023-08-20 21:55:11,962 - INFO - logging_and_debugging LOGGING LEVEL 20 -info -Level 20 is for general information
# 2023-08-20 21:55:11,963 - WARNING - logging_and_debugging LOGGING LEVEL 30 -warning -Level 30 is to produce warnings.
# 2023-08-20 21:55:11,963 - ERROR - logging_and_debugging LOGGING LEVEL 40 -error -Level 40 is for error messages that dont stop the code
# 2023-08-20 21:55:11,963 - CRITICAL - logging_and_debugging LOGGING LEVEL 50 -critical -Level 50 is for critical level errors that stop code
# 2023-08-20 21:55:12,096 - INFO - Imported existing <module 'comtypes.gen' from 'C:\\Users\\josep\\anaconda3\\lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 2023-08-20 21:55:12,096 - INFO - Using writeable comtypes cache directory: 'C:\Users\josep\anaconda3\lib\site-packages\comtypes\gen'
# 2023-08-20 21:56:34,430 - INFO - PERFORMANCE logging_and_debugging The total process duration was:82.48
# 2023-08-20 21:56:34,431 - INFO - PERFORMANCE logging_and_debugging Stop Time = 2023-08-20 21:56:34
# 2023-08-20 21:56:34,431 - INFO - PERFORMANCE logging_and_debugging Low process duration less than 3 minutes:82.48
# 2023-08-20 21:56:34,431 - INFO - PERFORMANCE logging_and_debugging Performance optimization is optional
# 2023-08-20 21:56:34,431 - INFO - END logging_and_debugging =============================================

# %% [markdown]
# # https://github.com/JoeEberle/
# # josepheberle@outlook.com

# %% [markdown]
# ![logging_and_debugging.png](attachment:logging_and_debugging.png)

# %% [markdown]
# ![developer.png](attachment:developer.png)
